# %%
### Stock Analysis

# %%
# Dependencies 
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import pandas_datareader.data as web
from sklearn import datasets
from scipy.stats import linregress

style.use('fivethirtyeight')
# Out:
# /Users/rolandonavarro/opt/anaconda3/lib/python3.7/site-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
# Pull different stocks

start = "2020-02-15"
end = "2020-04-17"

# %%
# Apple stock 
aapl_df = web.DataReader('AAPL','yahoo', start, end)
aapl_df['Change'] = ((aapl_df['Close']-aapl_df['Open'])/aapl_df['Open']) * 100
aapl_df['Volume'] = aapl_df['Volume']/1000000
aapl_df.head()
# Out:
#                   High         Low        Open       Close   Volume  \
# Date
# 2020-02-18  319.750000  314.609985  315.359985  319.000000  38.1328
# 2020-02-19  324.570007  320.000000  320.000000  323.619995  23.4960
# 2020-02-20  324.649994  318.209991  322.630005  320.299988  25.1415
# 2020-02-21  320.450012  310.500000  318.619995  313.049988  32.3885
# 2020-02-24  304.179993  289.230011  297.260010  298.179993  55.5488
#
#              Adj Close    Change
# Date
# 2020-02-18  319.000000  1.154241
# 2020-02-19  323.619995  1.131248
# 2020-02-20  320.299988 -0.722195
# 2020-02-21  313.049988 -1.748166
# 2020-02-24  298.179993  0.309488

# %%
# S&P 500
sp5_df = web.DataReader('^GSPC','yahoo', start, end)
sp5_df['Change'] = ((sp5_df['Close']-sp5_df['Open'])/sp5_df['Open']) * 100
sp5_df['Volume'] = sp5_df['Volume']/1000000
sp5_df.head()
# Out:
#                    High          Low         Open        Close   Volume  \
# Date
# 2020-02-18  3375.010010  3355.610107  3369.040039  3370.290039  3746.72
# 2020-02-19  3393.520020  3378.830078  3380.389893  3386.149902  3600.15
# 2020-02-20  3389.149902  3341.020020  3380.449951  3373.229980  4007.32
# 2020-02-21  3360.760010  3328.449951  3360.500000  3337.750000  3899.27
# 2020-02-24  3259.810059  3214.649902  3257.610107  3225.889893  4842.96
#
#               Adj Close    Change
# Date
# 2020-02-18  3370.290039  0.037103
# 2020-02-19  3386.149902  0.170395
# 2020-02-20  3373.229980 -0.213580
# 2020-02-21  3337.750000 -0.676983
# 2020-02-24  3225.889893 -0.973727

# %%
# Gold 
gold_df = web.DataReader('GOLD','yahoo', start, end)
gold_df['Change'] = ((gold_df['Close']-gold_df['Open'])/gold_df['Open']) * 100
gold_df['Volume'] = gold_df['Volume']/1000000
gold_df.head()
# Out:
#                  High        Low       Open      Close   Volume  Adj Close  \
# Date
# 2020-02-18  20.650000  19.750000  19.850000  20.580000  27.9619  20.511694
# 2020-02-19  21.040001  20.400000  20.809999  21.000000  20.1832  20.930300
# 2020-02-20  21.309999  20.719999  20.940001  20.770000  16.5935  20.701063
# 2020-02-21  21.610001  21.170000  21.450001  21.440001  19.9560  21.368839
# 2020-02-24  22.570000  21.730000  22.500000  22.030001  29.3542  21.956881
#
#               Change
# Date
# 2020-02-18  3.677579
# 2020-02-19  0.913025
# 2020-02-20 -0.811844
# 2020-02-21 -0.046621
# 2020-02-24 -2.088886

# %%
# Crude Oil (CL=F)
oil_df = web.DataReader('CL=F','yahoo', start, end)
oil_df['Change'] = ((oil_df['Close']-oil_df['Open'])/oil_df['Open']) * 100
oil_df['Volume'] = oil_df['Volume']/1000000
oil_df.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close  \
# Date
# 2020-02-16  52.410000  52.099998  52.200001  52.180000  0.019935  52.180000
# 2020-02-18  52.410000  50.880001  52.230000  52.049999  0.607343  52.049999
# 2020-02-19  53.660000  51.930000  52.119999  53.290001  0.221774  53.290001
# 2020-02-20  54.500000  53.220001  53.500000  53.779999  0.113683  53.779999
# 2020-02-21  53.860001  52.549999  53.740002  53.380001  0.676179  53.380001
#
#               Change
# Date
# 2020-02-16 -0.038315
# 2020-02-18 -0.344630
# 2020-02-19  2.244823
# 2020-02-20  0.523362
# 2020-02-21 -0.669893

# %%
# Utilities companies are not hit as hard compaerd to other industries. For example Consolidated Edison
# is one of the oldes companies in the stock market and as you can see they are not affected as much
# by the virus

ed_df = web.DataReader('ED','yahoo', start, end)
ed_df['Change'] = ((ed_df['Close']-ed_df['Open'])/ed_df['Open']) * 100
ed_df['Volume'] = ed_df['Volume']/1000000
ed_df.head()
# Out:
#                  High        Low       Open      Close  Volume  Adj Close  \
# Date
# 2020-02-18  94.580002  93.629997  93.720001  94.349998  2.1727  94.349998
# 2020-02-19  94.580002  93.739998  94.269997  93.879997  1.0299  93.879997
# 2020-02-20  94.650002  93.629997  93.870003  94.580002  1.3190  94.580002
# 2020-02-21  91.680000  89.269997  91.209999  90.180000  3.9769  90.180000
# 2020-02-24  90.129997  88.599998  89.459999  88.889999  2.3934  88.889999
#
#               Change
# Date
# 2020-02-18  0.672212
# 2020-02-19 -0.413705
# 2020-02-20  0.756364
# 2020-02-21 -1.129261
# 2020-02-24 -0.637156

# %%
# Drop index to plot Volume vs Price change
d_index = aapl_df.reset_index()
# aapl_df[['Volume','Change']]
aapl_plot = d_index[['Volume','Change']]

# %%
# Apple volume Graph
avol_df = pd.DataFrame(aapl_df['Volume'])
avol_df.plot(figsize=(15, 10))
plt.title('Apple Volume')
plt.savefig('../WebVisualization/Visualizations/aapl_volume.png')

# %%
# Apple price change 
apch_df = pd.DataFrame(aapl_df['Change'])
apch_df.plot(figsize=(16, 10))
plt.title('Apple Price')
plt.savefig('../WebVisualization/Visualizations/aapl_price.png')

# %%
# S&P 500 Volume Graph
sp5_vol = pd.DataFrame(sp5_df['Volume'])
sp5_vol.plot(figsize=(16,10))
plt.title('S&P 500 Volume')
plt.savefig('../WebVisualization/Visualizations/sp5_volume.png')

# %%
# S&P 500 Price Change Graph
sp5_p = pd.DataFrame(sp5_df['Change'])
sp5_p.plot(figsize=(16,10))
plt.title('S&P 500 Price Change')
plt.savefig('../WebVisualization/Visualizations/sp5_price.png')

# %%
# Oil Volume Graph
oil_v = pd.DataFrame(oil_df['Volume'])
oil_v.plot(figsize= (16,10))
plt.title('Oil Volume')
plt.savefig('../WebVisualization/Visualizations/oil_volume.png')

# %%
# Oil Price Change Graph
oil_p = pd.DataFrame(oil_df['Change'])
oil_p.plot(figsize= (16,10))
plt.title('Oil Price Change')
plt.savefig('../WebVisualization/Visualizations/oil_price.png')

# %%
# Consolidated Edison Graph
ed_p = pd.DataFrame(ed_df['Change'])
ed_p.plot(figsize= (16,10))
plt.title('Consolidated Edison Price Change')
plt.savefig('../WebVisualization/Visualizations/ce_price.png')

# %%
# Consolidated Edison Graph
ed_v = pd.DataFrame(ed_df['Volume'])
ed_v.plot(figsize= (16,10))
plt.title('Consolidated Edison Volme')
plt.savefig('../WebVisualization/Visualizations/ce_volume.png')

# %%
# Drop index to plot Volume vs Price change
d_index = aapl_df.reset_index()
# aapl_df[['Volume','Change']]
aapl_plot = d_index[['Volume','Change']]

# %%
# Volume vs Change in price of apple stock
x_values = aapl_plot['Volume']
y_values = aapl_plot['Change']

plt.scatter(x_values,y_values)#, label='skitscat', color='k', s=25, marker="o")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title('Volume vs Change in stock price')
plt.xlabel('Volume in Millions')
plt.ylabel('Change')
print(f"The r-squared is: {rvalue}")
print(slope, stderr)
plt.savefig('../WebVisualization/Visualizations/Vol_vs_price.png')
plt.show()
# Out:
# The r-squared is: 0.015865654143153433
# 0.0021582915026631456 0.02124249490389827

# %%
# Change in price of different stocks and see if there is any correlation between them

fig, ax = plt.subplots()
ax.plot(oil_df['Change'], color='purple', label='Oil')
ax.plot(ed_df['Change'], color ='blue', label='ED')
ax.plot(aapl_df['Change'], color ='red', label='Apple')
ax.plot(sp5_df['Change'], color ='green', label='S&P 500 Index')
plt.title('Price Change')
fig.set_size_inches(16, 10)
plt.legend()
plt.savefig('../WebVisualization/Visualizations/Stock_prices.png')

# %%
# Graph S&P, AAPL, GOLD in one graph to see how they change over time with the virus
