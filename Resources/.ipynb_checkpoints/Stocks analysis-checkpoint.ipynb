# %%
### Stock Analysis

# %%
# Dependencies 
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import pandas_datareader.data as web
from sklearn import datasets
from scipy.stats import linregress

style.use('fivethirtyeight')
# Out:
# /Users/rolandonavarro/opt/anaconda3/lib/python3.7/site-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
# Pull different stocks

start = "2020-02-15"
end = "2020-04-17"

# %%
# Apple stock 
aapl_df = web.DataReader('AAPL','yahoo', start, end)
aapl_df['Change'] = ((aapl_df['Close']-aapl_df['Open'])/aapl_df['Open']) * 100
aapl_df['Volume'] = aapl_df['Volume']/1000000
aapl_df.head()
# Out:
#                   High         Low        Open       Close   Volume  \
# Date
# 2020-02-18  319.750000  314.609985  315.359985  319.000000  38.1328
# 2020-02-19  324.570007  320.000000  320.000000  323.619995  23.4960
# 2020-02-20  324.649994  318.209991  322.630005  320.299988  25.1415
# 2020-02-21  320.450012  310.500000  318.619995  313.049988  32.3885
# 2020-02-24  304.179993  289.230011  297.260010  298.179993  55.5488
#
#              Adj Close    Change
# Date
# 2020-02-18  319.000000  1.154241
# 2020-02-19  323.619995  1.131248
# 2020-02-20  320.299988 -0.722195
# 2020-02-21  313.049988 -1.748166
# 2020-02-24  298.179993  0.309488

# %%
# aapl_df['Volume'] = aapl_df['Volume']*1000000
aapl_df
# Out:
#                   High         Low        Open       Close    Volume  \
# Date
# 2020-02-18  319.750000  314.609985  315.359985  319.000000   38.1328
# 2020-02-19  324.570007  320.000000  320.000000  323.619995   23.4960
# 2020-02-20  324.649994  318.209991  322.630005  320.299988   25.1415
# 2020-02-21  320.450012  310.500000  318.619995  313.049988   32.3885
# 2020-02-24  304.179993  289.230011  297.260010  298.179993   55.5488
# 2020-02-25  302.529999  286.130005  300.950012  288.079987   57.6684
# 2020-02-26  297.880005  286.500000  286.529999  292.649994   49.5137
# 2020-02-27  286.000000  272.959991  281.100006  273.519989   80.1514
# 2020-02-28  278.410004  256.369995  257.260010  273.359985  106.7212
# 2020-03-02  301.440002  277.720001  282.279999  298.809998   85.3493
# 2020-03-03  304.000000  285.799988  303.670013  289.320007   79.8689
# 2020-03-04  303.399994  293.130005  296.440002  302.739990   54.7946
# 2020-03-05  299.549988  291.410004  295.519989  292.920013   46.8932
# 2020-03-06  290.820007  281.230011  282.000000  289.029999   56.5442
# 2020-03-09  278.089996  263.000000  263.750000  266.170013   71.6862
# 2020-03-10  286.440002  269.369995  277.140015  285.339996   71.3225
# 2020-03-11  281.220001  271.859985  277.390015  275.429993   63.8997
# 2020-03-12  270.000000  248.000000  255.940002  248.229996  104.6185
# 2020-03-13  279.920013  252.949997  264.890015  277.970001   92.6830
# 2020-03-16  259.079987  240.000000  241.949997  242.210007   80.6059
# 2020-03-17  257.609985  238.399994  247.509995  252.860001   81.0140
# 2020-03-18  250.000000  237.119995  239.770004  246.669998   75.0584
# 2020-04-07  259.429993 -4.198669
# 2020-04-08  266.070007  1.267419
# 2020-04-09  267.989990 -0.264243
# 2020-04-13  273.250000  1.841155
# 2020-04-14  287.049988  2.517853
# 2020-04-15  284.429993  0.718838
# 2020-04-16  286.690002 -0.240101
# 2020-04-17  282.799988 -0.663885

# %%
# S&P 500
sp5_df = web.DataReader('^GSPC','yahoo', start, end)
sp5_df['Change'] = ((sp5_df['Close']-sp5_df['Open'])/sp5_df['Open']) * 100
sp5_df.head()
# Out:
#                    High          Low         Open        Close      Volume  \
# Date
# 2020-02-18  3375.010010  3355.610107  3369.040039  3370.290039  3746720000
# 2020-02-19  3393.520020  3378.830078  3380.389893  3386.149902  3600150000
# 2020-02-20  3389.149902  3341.020020  3380.449951  3373.229980  4007320000
# 2020-02-21  3360.760010  3328.449951  3360.500000  3337.750000  3899270000
# 2020-02-24  3259.810059  3214.649902  3257.610107  3225.889893  4842960000
#
#               Adj Close    Change
# Date
# 2020-02-18  3370.290039  0.037103
# 2020-02-19  3386.149902  0.170395
# 2020-02-20  3373.229980 -0.213580
# 2020-02-21  3337.750000 -0.676983
# 2020-02-24  3225.889893 -0.973727

# %%
# Gold 
gold_df = web.DataReader('GOLD','yahoo', start, end)
sp5_df['Change'] = ((sp5_df['Close']-sp5_df['Open'])/sp5_df['Open']) * 100
gold_df.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2020-02-18  20.650000  19.750000  19.850000  20.580000  27961900.0  20.511694
# 2020-02-19  21.040001  20.400000  20.809999  21.000000  20183200.0  20.930300
# 2020-02-20  21.309999  20.719999  20.940001  20.770000  16593500.0  20.701063
# 2020-02-21  21.610001  21.170000  21.450001  21.440001  19956000.0  21.368839
# 2020-02-24  22.570000  21.730000  22.500000  22.030001  29354200.0  21.956881

# %%
# Crude Oil (CL=F)
oil_df = web.DataReader('CL=F','yahoo', start, end)
oil_df['Change'] = ((oil_df['Close']-oil_df['Open'])/oil_df['Open']) * 100
oil_df.head()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close  \
# Date
# 2020-02-16  52.410000  52.099998  52.200001  52.180000   19935.0  52.180000
# 2020-02-18  52.410000  50.880001  52.230000  52.049999  607343.0  52.049999
# 2020-02-19  53.660000  51.930000  52.119999  53.290001  221774.0  53.290001
# 2020-02-20  54.500000  53.220001  53.500000  53.779999  113683.0  53.779999
# 2020-02-21  53.860001  52.549999  53.740002  53.380001  676179.0  53.380001
#
#               Change
# Date
# 2020-02-16 -0.038315
# 2020-02-18 -0.344630
# 2020-02-19  2.244823
# 2020-02-20  0.523362
# 2020-02-21 -0.669893

# %%
# Utilities companies are not hit as hard compaerd to other industries. For example Consolidated Edison
# is one of the oldes companies in the stock market and as you can see they are not affected as much
# by the virus

ed_df = web.DataReader('ED','yahoo', start, end)
ed_df['Change'] = ((ed_df['Close']-ed_df['Open'])/ed_df['Open']) * 100
ed_df.head()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close  \
# Date
# 2020-02-18  94.580002  93.629997  93.720001  94.349998  2172700.0  94.349998
# 2020-02-19  94.580002  93.739998  94.269997  93.879997  1029900.0  93.879997
# 2020-02-20  94.650002  93.629997  93.870003  94.580002  1319000.0  94.580002
# 2020-02-21  91.680000  89.269997  91.209999  90.180000  3976900.0  90.180000
# 2020-02-24  90.129997  88.599998  89.459999  88.889999  2393400.0  88.889999
#
#               Change
# Date
# 2020-02-18  0.672212
# 2020-02-19 -0.413705
# 2020-02-20  0.756364
# 2020-02-21 -1.129261
# 2020-02-24 -0.637156

# %%
# Drop index to plot Volume vs Price change
d_index = aapl_df.reset_index()
# aapl_df[['Volume','Change']]
aapl_plot = d_index[['Volume','Change']]

# %%
# Apple volume Graph
avol_df = pd.DataFrame(aapl_df['Volume'])
avol_df.plot(figsize=(20, 10))

# %%
# Apple price change 
apch_df = pd.DataFrame(aapl_df['Change'])
apch_df.plot()
plt.savefig('../Visualizations/figure.jpg')

# %%
# S&P 500 Volume Graph
sp5_df = pd.DataFrame(sp5_df['Volume'])
sp5_df.plot()

# %%
# S&P 500 Price Change Graph
sp5_df = pd.DataFrame(sp5_df['Change'])
sp5_df.plot()

# %%
# Oil Volume Graph
oil_df = pd.DataFrame(oil_df['Volume'])
oil_df.plot()

# %%
# Oil Price Change Graph
oil_df = pd.DataFrame(oil_df['Change'])
oil_df.plot()

# %%
# Consolidated Edison Graph
ed_df = pd.DataFrame(ed_df['Volume'])
ed_df.plot()

# %%
# Consolidated Edison Graph
ed_df = pd.DataFrame(ed_df['Volume'])
ed_df.plot()

# %%
# Drop index to plot Volume vs Price change
d_index = aapl_df.reset_index()
# aapl_df[['Volume','Change']]
aapl_plot = d_index[['Volume','Change']]
# Out:
# 470.2495

# %%
# Volume vs Change in price of apple stock
x_values = aapl_plot['Volume']
y_values = aapl_plot['Change']

plt.scatter(x_values,y_values, label='skitscat', color='k', s=25, marker="o")

(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.title('Volume vs Change of price')
plt.xlabel('Volume in Millions')
plt.ylabel('Change')
print(f"The r-squared is: {rvalue}")
print(slope, stderr)
plt.show()
# Out:
# The r-squared is: -0.08087637201115169
# -0.0018754553943445365 0.0004569039495468015

# %%
vol_df = pd.DataFrame(aapl_df['Volume'])
# Out:
#               Volume
# Date
# 2010-02-16  135.9344
# 2010-02-17  109.0992
# 2010-02-18  105.7063
# 2010-02-19  103.8674
# 2010-02-22   97.6409
# ...              ...
# 2020-04-13   32.7557
# 2020-04-14   48.7487
# 2020-04-15   32.7886
# 2020-04-16   38.8458
# 2020-04-17   53.7566
#
# [2561 rows x 1 columns]

# %%
# Graph S&P, AAPL, GOLD in one graph to see how they change over time with the virus
